# %% [markdown]
# <a href="https://colab.research.google.com/github/scoobiii/ONS_Dados_Abertos/blob/main/SunStream_SIN_GERACAO_USINA_2021.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GERACAO USINA 2021

# %%
from urllib import request
import pandas as  pd
import numpy as np

# %% [markdown]
# **1. Download do Dataset do Portal de Dados Abertos**

# %%
file_url = 'https://ons-dl-prod-opendata.s3.amazonaws.com/dataset/geracao_usina_ho/GERACAO_USINA_2021.csv'
source_file = 'GERACAO_USINA_2021.csv'
request.urlretrieve(file_url , source_file )
# Out:
# ('GERACAO_USINA_2021.csv', <http.client.HTTPMessage at 0x7f0c85ca0be0>)

# %% [markdown]
# **2. Importar arquivo**

# %%
dataframe = pd.read_csv(source_file, sep=';',encoding = "utf-8")

if (dataframe.empty) :
    print('DATAFRAME VAZIO')
else:
  print('shape:', dataframe.shape)
  print('columns:', dataframe.columns)
# Out:
# shape: (4868160, 11)
# columns: Index(['din_instante', 'id_subsistema', 'nom_subsistema', 'id_estado',
#        'nom_estado', 'cod_modalidadeoperacao', 'nom_tipousina',
#        'nom_tipocombustivel', 'nom_usina', 'ceg', 'val_geracao'],
#       dtype='object')

# %%
dataframe.head(3)
# Out:
#           din_instante id_subsistema nom_subsistema id_estado nom_estado  \
# 0  2021-01-01 00:00:00             N          NORTE        AM   AMAZONAS
# 1  2021-01-01 00:00:00             N          NORTE        AM   AMAZONAS
# 2  2021-01-01 00:00:00             N          NORTE        AM   AMAZONAS
#
#   cod_modalidadeoperacao  nom_tipousina nom_tipocombustivel nom_usina  \
# 0                 TIPO I  HIDROELÉTRICA          Hidráulica   Balbina
# 1               TIPO III        TÉRMICA         Óleo Diesel  Flores 1
# 2               TIPO III        TÉRMICA         Óleo Diesel  Flores 4
#
#                      ceg  val_geracao
# 0  UHE.PH.AM.000190-2.01      106.554
# 1  UTE.PE.AM.029192-7.01        0.000
# 2  UTE.PE.AM.029192-7.01        0.000

# %%
dataframe.head()
# Out:
#           din_instante id_subsistema nom_subsistema id_estado nom_estado  \
# 0  2021-01-01 00:00:00             N          NORTE        AM   AMAZONAS
# 1  2021-01-01 00:00:00             N          NORTE        AM   AMAZONAS
# 2  2021-01-01 00:00:00             N          NORTE        AM   AMAZONAS
# 3  2021-01-01 00:00:00             N          NORTE        AM   AMAZONAS
# 4  2021-01-01 00:00:00             N          NORTE        AM   AMAZONAS
#
#   cod_modalidadeoperacao  nom_tipousina nom_tipocombustivel        nom_usina  \
# 0                 TIPO I  HIDROELÉTRICA          Hidráulica          Balbina
# 1               TIPO III        TÉRMICA         Óleo Diesel         Flores 1
# 2               TIPO III        TÉRMICA         Óleo Diesel         Flores 4
# 3                 TIPO I        TÉRMICA                 Gás        Aparecida
# 4                 TIPO I        TÉRMICA                 Gás  Cristiano Rocha
#
#                      ceg  val_geracao
# ...

# %%
dataframe
# Out:
#                 din_instante id_subsistema nom_subsistema id_estado  \
# 0        2021-01-01 00:00:00             N          NORTE        AM
# 1        2021-01-01 00:00:00             N          NORTE        AM
# 2        2021-01-01 00:00:00             N          NORTE        AM
# 3        2021-01-01 00:00:00             N          NORTE        AM
# 4        2021-01-01 00:00:00             N          NORTE        AM
# ...                      ...           ...            ...       ...
# 4868155  2021-12-31 23:00:00            SE        SUDESTE        SP
# 4868156  2021-12-31 23:00:00            SE        SUDESTE        SP
# 4868157  2021-12-31 23:00:00            SE        SUDESTE        TO
# 4868158  2021-12-31 23:00:00            SE        SUDESTE        TO
# 4868159  2021-12-31 23:00:00            SE        SUDESTE        TO
#
#         nom_estado      cod_modalidadeoperacao  nom_tipousina  \
# 0         AMAZONAS                      TIPO I  HIDROELÉTRICA
# ...

# %% [markdown]
# **3.Explorando o conteúdo do arquivo**

# %%
dataframe.count()
# Out:
# din_instante              4868160
# id_subsistema             4868160
# nom_subsistema            4868160
# id_estado                 4868160
# nom_estado                4868160
# cod_modalidadeoperacao    4868160
# nom_tipousina             4868160
# nom_tipocombustivel       4863192
# nom_usina                 4868160
# ceg                       4868160
# val_geracao               4860888
# dtype: int64

# %% [markdown]
# **3.2 Quantidade de valores nulos**

# %%
dataframe.isnull().sum()
# Out:
# din_instante                 0
# id_subsistema                0
# nom_subsistema               0
# id_estado                    0
# nom_estado                   0
# cod_modalidadeoperacao       0
# nom_tipousina                0
# nom_tipocombustivel       4968
# nom_usina                    0
# ceg                          0
# val_geracao               7272
# dtype: int64

# %% [markdown]
# **4. Estatísticas**

# %%
# Variaveis do tipo "TEXTOS"
dataframe.describe(include=[object])
# Out:
#                din_instante id_subsistema nom_subsistema id_estado nom_estado  \
# count               4868160       4868160        4868160   4868160    4868160
# unique                 8760             4              5        28         28
# top     2021-03-10 11:00:00            SE        SUDESTE        BA      BAHIA
# freq                    596       2016288        2007528    625440     625440
#
#        cod_modalidadeoperacao  nom_tipousina nom_tipocombustivel  nom_usina  \
# count                 4868160        4868160             4863192    4868160
# unique                      7              5                  11        655
# top                    TIPO I  HIDROELÉTRICA          Hidráulica  Simplício
# freq                  2101032        1789464             1789464      17520
#
#             ceg
# count   4868160
# unique      370
# top           -
# freq    1980696

# %%
# Variaveis do tipo "NUMERO"
dataframe.describe(include=[np.number])
 
# ou dataframe.describe(exclude=[object])
# Out:
#         val_geracao
# count  4.860888e+06
# mean   1.297298e+02
# std    4.004803e+02
# min    0.000000e+00
# 25%    1.650000e+00
# 50%    3.469500e+01
# 75%    1.078860e+02
# max    1.101831e+04

# %%
# Estatistica sobre uma das colunas selecionadas
dataframe.val_geracao.describe()
# Out:
# count    4.860888e+06
# mean     1.297298e+02
# std      4.004803e+02
# min      0.000000e+00
# 25%      1.650000e+00
# 50%      3.469500e+01
# 75%      1.078860e+02
# max      1.101831e+04
# Name: val_geracao, dtype: float64

# %% [markdown]
# **5. Análise sobre os resultados - Foco em Geração**
#
# *A função value_counts() do pandas é valiosíssima nas análises de dados, o que ela faz é verificar a contagem de dados iguais em um dataframe ou em uma coluna, e retorna uma Series com esse resultado.*

# %%
dataframe.nom_usina.value_counts(ascending=False)
# Out:
# Simplício                     17520
# Rondon II                     17520
# São José                      16008
# Itumbiara                     10584
# Caçu                           8760
#                               ...
# Ventos de Santa Martina 09     1152
# Conj. Chafariz Norte            888
# Conj. Ventos da Bahia III       696
# Conj. Lagoa do Barro II         576
# Guaricana                       384
# Name: nom_usina, Length: 655, dtype: int64

# %% [markdown]
# *A função duplicated() nos retorna uma série booleana denotando linhas duplicadas. Os resultados são Verdadeiro(True) e Falso(False), sendo verdadeiros os valores duplicados.*

# %%
resultado = dataframe.duplicated(subset=['nom_usina'], keep=False)
dataframe[resultado]
# Out:
#                 din_instante id_subsistema nom_subsistema id_estado  \
# 0        2021-01-01 00:00:00             N          NORTE        AM
# 1        2021-01-01 00:00:00             N          NORTE        AM
# 2        2021-01-01 00:00:00             N          NORTE        AM
# 3        2021-01-01 00:00:00             N          NORTE        AM
# 4        2021-01-01 00:00:00             N          NORTE        AM
# ...                      ...           ...            ...       ...
# 4868155  2021-12-31 23:00:00            SE        SUDESTE        SP
# 4868156  2021-12-31 23:00:00            SE        SUDESTE        SP
# 4868157  2021-12-31 23:00:00            SE        SUDESTE        TO
# 4868158  2021-12-31 23:00:00            SE        SUDESTE        TO
# 4868159  2021-12-31 23:00:00            SE        SUDESTE        TO
#
#         nom_estado      cod_modalidadeoperacao  nom_tipousina  \
# 0         AMAZONAS                      TIPO I  HIDROELÉTRICA
# ...

# %% [markdown]
# **6. Conclusão**
#
# Não temos linhas repetidas no Dataset
# Observamos que o resultado quantitativo da estatística para "nom_usina" teve count= 4868160 e unique= 17520	sugerindo repetição.
#
# Numa investigação específica sobre nom_usina, encontramos 3 nomes iguais POREM para para USINAS DIFERENTES.
